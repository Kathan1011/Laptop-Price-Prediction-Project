# %%
# Importing Necessary Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# Importing the dataset
df = pd.read_csv('laptop_data.csv')
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
df.drop(columns=["Unnamed: 0"],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df["Ram"]=df["Ram"].str.replace("GB"," ")
df["Weight"]=df["Weight"].str.replace("kg"," ")

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8             128GB SSD
# 1        Intel Core i5 1.8GHz   8   128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8             256GB SSD
# 3        Intel Core i7 2.7GHz  16             512GB SSD
# 4        Intel Core i5 3.1GHz   8             256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37    71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34    47895.5232
# ...

# %%
df["Ram"]=df["Ram"].astype("int64")
df["Weight"]=df["Weight"].astype("float64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int64
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 112.1+ KB

# %% [markdown]
# # Data Visualization

# %%
df["Company"].value_counts().plot(kind='bar',color='green')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar',color='cyan')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %% [markdown]
# # Feature Engineering

# %%
# Feature Engineering for Touchscreen 
df['Touchscreen']=df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches             ScreenResolution  \
# 430  Samsung    Netbook    11.6                     1366x768
# 392     Acer   Notebook    15.6           IPS Panel 1366x768
# 734   Lenovo   Notebook    13.3  IPS Panel Full HD 1920x1080
# 344     Dell  Ultrabook    13.3            Full HD 1920x1080
# 884     Dell   Notebook    15.6                     1366x768
#
#                                       Cpu  Ram              Memory  \
# 430  Intel Celeron Dual Core N3060 1.6GHz    4  16GB Flash Storage
# 392            Intel Core i5 8250U 1.6GHz   12             1TB HDD
# 734            Intel Core i5 7200U 2.5GHz    8           256GB SSD
# 344            Intel Core i7 8550U 1.8GHz    8           256GB SSD
# 884  Intel Pentium Quad Core N3710 1.6GHz    4           500GB HDD
#
#                         Gpu       OpSys  Weight       Price  Touchscreen
# 430   Intel HD Graphics 400   Chrome OS    1.15  14332.3200            0
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar',color='purple')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
# Feature Engineering for Ips
df['Ips']=df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df['Ips'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Ips'],y=df['Price'])
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %%
new=df["ScreenResolution"].str.split('x',n=1,expand=True)

# %%
df['X_res']=new[0]
df['Y_res']=new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['X_res']=df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['X_res']=df['X_res'].astype('int64')
df['Y_res']=df['Y_res'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int64
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int64
#  14  Y_res             1303 non-null   int64
# dtypes: float64(3), int64(5), object(7)
# memory usage: 152.8+ KB

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
# Taking square root of X_res and Y_res and dividing by Inches to create a new column named as Ppi

df['Ppi']=(((df['X_res']**2)+(df['Y_res']**2))**0.5/df['Inches']).astype('float64')

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# Ppi            0.473487
# Name: Price, dtype: float64

# %%
# Dropping ScreenResolution,Inches,X_res,Y_res as they are no longer needed as Ppi is the combination of these columns

df.drop(columns=['ScreenResolution'] ,inplace=True)

# %%
df.drop(columns=['Inches','X_res','Y_res'] ,inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           Ppi
# 0  226.983005
# 1  127.677940
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['Cpu_Name'] = df['Cpu'].apply(lambda x:' '.join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           Ppi       Cpu_Name
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu_brand'] = df['Cpu_Name'].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           Ppi       Cpu_Name      Cpu_brand
# ...

# %%
df.sample(5)
# Out:
#      Company   TypeName                          Cpu  Ram  \
# 939     Dell     Gaming  Intel Core i7 6820HK 2.7GHz   16
# 291     Asus     Gaming  Intel Core i7 7700HQ 2.8GHz    8
# 546   Lenovo   Notebook   Intel Core i5 7200U 2.5GHz    4
# 768  Samsung  Ultrabook   Intel Core i7 7500U 2.7GHz    8
# 784   Lenovo  Ultrabook   Intel Core i7 7500U 2.7GHz   16
#
#                    Memory                      Gpu       OpSys  Weight  \
# 939  512GB SSD +  1TB HDD  Nvidia GeForce GTX 1080  Windows 10    4.36
# 291               1TB HDD  Nvidia GeForce GTX 1050  Windows 10    3.00
# 546             500GB HDD    Intel HD Graphics 620  Windows 10    1.87
# 768             256GB SSD    Intel HD Graphics 620  Windows 10    1.31
# 784             512GB SSD    Intel HD Graphics 620  Windows 10    1.70
#
#          Price  Touchscreen  Ips         Ppi       Cpu_Name      Cpu_brand
# 939  146946.24            0    0  169.780899  Intel Core i7  Intel Core i7
# ...

# %%
df['Cpu_brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Cpu_brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Cpu','Cpu_Name'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  Ips         Ppi      Cpu_brand
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Memory']=df['Memory'].str.replace('GB','')
df['Memory']=df['Memory'].str.replace('TB','000')

# %%
df.sample(10)
# Out:
#      Company            TypeName  Ram               Memory  \
# 238     Asus              Gaming   32  512 SSD +  1000 HDD
# 1198    Acer            Notebook    4             1000 HDD
# 706     Acer  2 in 1 Convertible    8              256 SSD
# 868     Acer            Notebook    8              256 SSD
# 1290    Dell            Notebook    6             1000 HDD
# 123       HP            Notebook   16              512 SSD
# 145     Asus           Ultrabook    8              256 SSD
# 257       HP            Notebook   16             1000 HDD
# 864     Dell           Ultrabook   16              512 SSD
# 326     Acer            Notebook    6             1000 HDD
#
#                                Gpu       OpSys  Weight      Price  \
# 238        Nvidia GeForce GTX 1080  Windows 10    4.70  207259.20
# 1198         Intel HD Graphics 500       Linux    2.10   14492.16
# 706         Intel UHD Graphics 620  Windows 10    1.60   53226.72
# ...

# %%
new=df['Memory'].str.split('+' ,n=1,expand=True)

# %%
new.sample(5)
# Out:
#              0           1
# 1124  1000 HDD        None
# 1089   500 HDD        None
# 301   256 SSD     1000 HDD
# 171   2000 HDD        None
# 1039   256 SSD        None

# %%
df['first']=new[0]
df['second']=new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  Ips         Ppi      Cpu_brand  \
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5
#
#                first second
# 0            128 SSD   None
# ...

# %%
def memory_ssd(x):
    if x.split()[1]=='SSD':
        return 1
    else:
        return 0

# %%
df['SSD1']=df['first'].apply(memory_ssd)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  Ips         Ppi      Cpu_brand  \
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5
#
#                first second  SSD1
# ...

# %%
def memory_hdd(x):
    if x.split()[1]=='HDD':
        return 1
    else:
        return 0

# %%
df['HDD1']=df['first'].apply(memory_hdd)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  Ips         Ppi      Cpu_brand  \
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5
#
#                first second  SSD1  HDD1
# ...

# %%
def memory_flash(x):
    if x.split()[1]=='Flash':
        return 1
    else:
        return 0

# %%
df['Flash Storage1']=df['first'].apply(memory_flash)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  Ips         Ppi      Cpu_brand  \
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5
#
#                first second  SSD1  HDD1  Flash Storage1
# ...

# %%
def memory_hybrid(x):
    if x.split()[1]=='Hybrid':
        return 1
    else:
        return 0

# %%
df['Hybrid Storage1']=df['first'].apply(memory_hybrid)

# %%
df.sample(10)
# Out:
#      Company            TypeName  Ram               Memory  \
# 540     Dell           Ultrabook    8              256 SSD
# 710   Lenovo              Gaming    8  128 SSD +  1000 HDD
# 1286  Lenovo            Notebook    2     64 Flash Storage
# 516       HP            Notebook    4             1000 HDD
# 705     Dell            Notebook    8              256 SSD
# 835     Dell              Gaming   16  256 SSD +  1000 HDD
# 826     Asus  2 in 1 Convertible    8              256 SSD
# 882     Asus            Notebook    4     32 Flash Storage
# 830    Razer              Gaming   32              512 SSD
# 1071      HP            Notebook    4              500 HDD
#
#                              Gpu       OpSys  Weight        Price  \
# 540       Intel UHD Graphics 620  Windows 10    1.20   74538.7200
# 710   Nvidia GeForce GTX 1050 Ti  Windows 10    2.50   66546.7200
# 1286           Intel HD Graphics  Windows 10    1.50   12201.1200
# ...

# %%
df['second'].fillna('0',inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  Ips         Ppi      Cpu_brand  \
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5
#
# ...

# %%
df['SSD2']=df['second'].apply(lambda x:1 if 'SSD' in x else 0)
df['HDD2']=df['second'].apply(lambda x:1 if 'HDD' in x else 0)
df['Flash2']=df['second'].apply(lambda x:1 if 'Flash' in x else 0)
df['Hyb2']=df['second'].apply(lambda x:1 if 'Hybrid' in x else 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Company          1303 non-null   object
#  1   TypeName         1303 non-null   object
#  2   Ram              1303 non-null   int64
#  3   Memory           1303 non-null   object
#  4   Gpu              1303 non-null   object
#  5   OpSys            1303 non-null   object
#  6   Weight           1303 non-null   float64
#  7   Price            1303 non-null   float64
#  8   Touchscreen      1303 non-null   int64
#  9   Ips              1303 non-null   int64
#  10  Ppi              1303 non-null   float64
#  11  Cpu_brand        1303 non-null   object
#  12  first            1303 non-null   object
#  13  second           1303 non-null   object
#  14  SSD1             1303 non-null   int64
#  15  HDD1             1303 non-null   int64
# ...

# %%
df['first']=df['first'].str.strip()
df['first']=df['first'].str.replace('SSD','')
df['first']=df['first'].str.replace('HDD','')
df['first']=df['first'].str.replace('Flash Storage','')
df['first']=df['first'].str.replace('Hybrid','')
df['second']=df['second'].str.replace('SSD','')
df['second']=df['second'].str.replace('HDD','')
df['second']=df['second'].str.replace('Flash Storage','')
df['second']=df['second'].str.replace('Hybrid','')

# %%
df["first"]=df["first"].astype(float)
df['second']=df['second'].astype(float)

# %%
df['SSD']=(df['first']*df['SSD1']+df['second']*df['SSD2'])

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  Ips  ...  second SSD1  HDD1  \
# 0  macOS    1.37   71378.6832            0    1  ...     0.0    1     0
# 1  macOS    1.34   47895.5232            0    0  ...     0.0    0     0
# 2  No OS    1.86   30636.0000            0    0  ...     0.0    1     0
# 3  macOS    1.83  135195.3360            0    1  ...     0.0    1     0
# 4  macOS    1.37   96095.8080            0    1  ...     0.0    1     0
#
#    Flash Storage1  Hybrid Storage1  SSD2  HDD2  Flash2  Hyb2    SSD
# ...

# %%
df['SSD']=(df['first']*df['SSD1']+df['second']*df['SSD2'])
df['HDD']=(df['first']*df['HDD1']+df['second']*df['HDD2'])
df['Flash_Storage']=(df['first']*df['Flash Storage1']+df['second']*df['Flash2'])
df['Hybrid']=(df['first']*df['Hybrid Storage1']+df['second']*df['Hyb2'])

# %%
df.drop(columns=['SSD1','HDD1','Flash Storage1','Hybrid Storage1','SSD2','HDD2','Flash2','Hyb2'],inplace=True)

# %%
df['SSD']=df['SSD'].astype(int)
df['HDD']=df['HDD'].astype(int)
df['Flash_Storage']=df['Flash_Storage'].astype(int)
df['Hybrid']=df['Hybrid'].astype(int)

# %%
df.drop(columns=['Memory','first','second'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         Ppi      Cpu_brand  SSD  HDD  \
# 0   71378.6832            0    1  226.983005  Intel Core i5  128    0
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5  256    0
# 3  135195.3360            0    1  220.534624  Intel Core i7  512    0
# 4   96095.8080            0    1  226.983005  Intel Core i5  256    0
#
#    Flash_Storage  Hybrid
# 0              0       0
# 1            128       0
# 2              0       0
# ...

# %%
df.corr()['Price']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# Ips              0.252208
# Ppi              0.473487
# SSD              0.670799
# HDD             -0.095476
# Flash_Storage   -0.040511
# Hybrid          -0.004769
# Name: Price, dtype: float64

# %%
# Dropping Hybrid and Flash_Storage for better results

df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         Ppi      Cpu_brand  SSD  HDD
# 0   71378.6832            0    1  226.983005  Intel Core i5  128    0
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5  256    0
# 3  135195.3360            0    1  220.534624  Intel Core i7  512    0
# 4   96095.8080            0    1  226.983005  Intel Core i5  256    0

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['Gpu_brand']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu_brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu_brand, dtype: int64

# %%
df = df[df['Gpu_brand']!='ARM']

# %%
df['Gpu_brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu_brand, dtype: int64

# %%
sns.barplot(x=df['Gpu_brand'],y=df['Price'])

plt.show()

# %%
df.drop(columns='Gpu',inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           Ppi      Cpu_brand  SSD  HDD Gpu_brand
# 0  226.983005  Intel Core i5  128    0     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5  256    0     Intel
# 3  220.534624  Intel Core i7  512    0       AMD
# 4  226.983005  Intel Core i5  256    0     Intel

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others'

# %%
df['Os'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           Ppi      Cpu_brand  SSD  HDD Gpu_brand      Os
# 0  226.983005  Intel Core i5  128    0     Intel     Mac
# 1  127.677940  Intel Core i5    0    0     Intel     Mac
# 2  141.211998  Intel Core i5  256    0     Intel  Others
# 3  220.534624  Intel Core i7  512    0       AMD     Mac
# 4  226.983005  Intel Core i5  256    0     Intel     Mac

# %%
df.drop(columns='OpSys',inplace=True)

# %%
sns.barplot(x=df['Os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df.corr()['Price']
# Out:
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# Ips            0.253320
# Ppi            0.475368
# SSD            0.670660
# HDD           -0.095925
# Name: Price, dtype: float64

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.to_csv('C:\\Users\\acer\\Desktop\\Python\\LaptopCleanedData.csv',index=False)

# %% [markdown]
# # Model Building

# %%
dummy=pd.get_dummies(df[['Company','TypeName','Cpu_brand','Gpu_brand','Os']],drop_first=True)
df=pd.concat([df,dummy],axis=1)

# %%
df=df.drop(['Company','TypeName','Cpu_brand','Gpu_brand','Os'],1)

# %%
X = df.drop(columns=['Price'])
Y = np.log(df['Price'])

# %%
X
# Out:
#       Ram  Weight  Touchscreen  Ips         Ppi  SSD   HDD  Company_Apple  \
# 0       8    1.37            0    1  226.983005  128     0              1
# 1       8    1.34            0    0  127.677940    0     0              1
# 2       8    1.86            0    0  141.211998  256     0              0
# 3      16    1.83            0    1  220.534624  512     0              1
# 4       8    1.37            0    1  226.983005  256     0              1
# ...   ...     ...          ...  ...         ...  ...   ...            ...
# 1298    4    1.80            1    1  157.350512  128     0              0
# 1299   16    1.30            1    1  276.053530  512     0              0
# 1300    2    1.50            0    0  111.935204    0     0              0
# 1301    6    2.19            0    0  100.454670    0  1000              0
# 1302    4    2.20            0    0  100.454670    0   500              0
#
#       Company_Asus  Company_Chuwi  ...  TypeName_Ultrabook  \
# ...

# %%
Y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=100)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=lr.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error

# %%
print(r2_score(Y_test,Y_pred))
print(mean_absolute_error(Y_test,Y_pred))
# Out:
# 0.8314048679404598
# 0.20230589136273266

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor()

# %%
knn.fit(X_train, Y_train)
# Out:
# KNeighborsRegressor()

# %%
Y_pred_knn = knn.predict(X_test)

# %%
r2_knn=r2_score(Y_test,Y_pred_knn)
r2_knn
# Out:
# 0.7982017950269017

# %%
from sklearn.tree import  DecisionTreeRegressor

# %%
dt=DecisionTreeRegressor()

# %%
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
Y_preddt=dt.predict(X_test)

# %%
r2_dt=r2_score(Y_test,Y_preddt)
r2_dt
# Out:
# 0.7797039371794674

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor()

# %%
rf.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
Y_predrf=rf.predict(X_test)

# %%
r2_rf=r2_score(Y_test,Y_predrf)
r2_rf
# Out:
# 0.8815526190693398
